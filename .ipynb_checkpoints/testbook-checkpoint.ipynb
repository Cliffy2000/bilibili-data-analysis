# %%
import jieba
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from snownlp import SnowNLP as nlp

# %%
outer = pd.read_excel('外页数据.xlsx')
inner1 = pd.read_excel('内页数据1.xlsx')
inner2 = pd.read_excel('内页数据2.xlsx')
comments_in = pd.read_excel('弹幕信息.xlsx')
comments_after = pd.read_csv('bilibili评论的数据.csv', encoding='utf-8', engine='python')

# %%
file_names = ['外页数据.xlsx', '内页数据1.xlsx', '内页数据2.xlsx', '弹幕信息.xlsx', 'bilibili评论的数据.csv']
file_reads = [outer, inner1, inner2, comments_in, comments_after]

for i in range(5):
    print('========', str(file_names[i]), '========\n', sep='')
    file_reads[i].info()
    print('\n\n\n')
# Out:
# ========外页数据.xlsx========
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
# 标题      1200 non-null object
# 播放量     1200 non-null object
# 弹幕量     1200 non-null object
# 作者      1200 non-null object
# 综合得分    1200 non-null int64
# 视频ID    1200 non-null int64
# 类别排名    1200 non-null int64
# 类别      1200 non-null object
# dtypes: int64(3), object(5)
# memory usage: 51.6+ KB
#
#
#
#
# ========内页数据1.xlsx========
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 9 columns):
# Unnamed: 0    1200 non-null int64
# 视频ID          1200 non-null int64
# 点赞数           1200 non-null int64
# 投币数           1200 non-null int64
# 收藏数           1200 non-null int64
# 分享数           1200 non-null int64
# 评论数           1199 non-null float64
# 播放量           1199 non-null float64
# 弹幕数           1199 non-null float64
# dtypes: float64(3), int64(6)
# memory usage: 84.4 KB
#
#
#
#
# ========内页数据2.xlsx========
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 6 columns):
# Unnamed: 0    1200 non-null int64
# 视频ID          1200 non-null int64
# 类别            1193 non-null object
# 更新时间          1200 non-null object
# rank          1200 non-null object
# 关键词           1193 non-null object
# dtypes: int64(2), object(4)
# memory usage: 37.6+ KB
#
#
#
#
# ========弹幕信息.xlsx========
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
# Unnamed: 0    120 non-null int64
# 视频ID          120 non-null int64
# 弹幕            120 non-null object
# dtypes: int64(2), object(1)
# memory usage: 2.4+ KB
#
#
#
#
# ========bilibili评论的数据.csv========
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44848 entries, 0 to 44847
# Data columns (total 19 columns):
# Unnamed: 0    44848 non-null int64
# 昵称            44833 non-null object
# 评论            44833 non-null object
# 主评论点赞数        32625 non-null float64
# time          44833 non-null object
# name1         11093 non-null object
# time1         11093 non-null object
# 子评论1          11093 non-null object
# like1         4350 non-null float64
# name2         6370 non-null object
# time2         6370 non-null object
# 子评论2          6370 non-null object
# like2         2716 non-null float64
# name3         4398 non-null object
# 子评论3          4397 non-null object
# time3         4398 non-null object
# like3         2147 non-null float64
# ID            44848 non-null int64
# 当前网页URL1      44848 non-null object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 4.3+ MB

# %%
count = 0
title_emotion_sum = 0
title_emotion_list = []
for title in outer['标题']:
    try:
        nlpObj = nlp(title)
        title_emotion = nlpObj.sentiments
        count += 1
        title_emotion_sum += title_emotion
        title_emotion_list.append(title_emotion)
        if count%5 == 0:
            print('Loading', '·'*int((count/5)%5), sep='', end='\r')
        if count%25 == 0:
            print('Loading        ', end='\r')
    except:
        continue
print('Title emotion calculations complete. ')
# Out:
# Title emotion calculations complete.

# %%
def check_emotion(s):
    nlpObj = nlp(s)
    score = nlpObj.sentiments
    return score

# %%
for i in range(25):
    title = outer['标题'][i]
    print(check_emotion(title))
# Out:
# 0.831159847586475
# 0.821076964289664
# 0.14655473726647683
# 0.12435368808396885
# 0.9976718979023993
# 0.6395645016668318
# 0.44571280093618326
# 0.27004645450631637
# 0.995160512379846
# 0.9999917290789405
# 0.752779596447843
# 0.8745648626118512
# 0.31763158374199074
# 0.3498766638881323
# 0.16607185584517647
# 0.9999740362651931
# 0.9035949219829893
# 0.5562627594902063
# 0.9595183313840081
# 0.8811822730562359
# 0.20431860383862732
# 0.5013366051602413
# 0.9882554723042266
# 0.9494798429285537
# 0.46926261637604527

# %%
title_emotion_sum / count
# Out:
# 0.7314487979908058

# %%
print(check_emotion('我很快乐'))
print(check_emotion('我很快乐!!'))
# Out:
# 0.971889316039116
# 0.9423348474889641

# %%
title_trimmed = []
count = 0
punctuations = '，。！@#￥%……&*（）——+-=【】、{}|；：’‘“”《》？/'
for title in outer['标题']:
    new = ''
    for char in title:
        if char in punctuations:
            continue
        new += str(char)
        
    title_trimmed.append(new)
    count += 1
    print('Current progress:', count, end='\r')
# Out:
# Current progress: 595
# Current progress: 1080
# Current progress: 1200

# %%
count = 0
title_emotion_sum_trimmed = 0
title_emotion_list_trimmed = []
for title in title_trimmed:
    try:
        nlpObj = nlp(title)
        title_emotion_trimmed = nlpObj.sentiments
        count += 1
        title_emotion_sum_trimmed += title_emotion_trimmed
        title_emotion_list_trimmed.append(title_emotion_trimmed)
        if count%5 == 0:
            print('Loading', '·'*int((count/5)%5), sep='', end='\r')
        if count%25 == 0:
            print('Loading        ', end='\r')
    except:
        continue
print('Title emotion calculations complete. ')
